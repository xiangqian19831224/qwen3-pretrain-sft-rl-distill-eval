# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-9de21cd0776947ec9ef2396f7110cb6d",  # Replace with your ModelScope SDK Token, see: https://modelscope.cn/my/myaccesstoken
    base_url="https://api-inference.modelscope.cn/v1/"
)

response = client.chat.completions.create(
    model="Qwen/Qwen3-32B",    # ModelScope model_id
    messages=[
        {
            'role': 'system',
            'content': 'You are a helpful assistant.'
        },
        {
            'role': 'user',
            'content': 'Write a quicksort in Python.'
        }
    ],
    stream=True
)

for chunk in response:
    if chunk.choices[0].delta.reasoning_content:
        print(chunk.choices[0].delta.reasoning_content, end='', flush=True)
    else:
        print(chunk.choices[0].delta.content, end='', flush=True)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[1], line 8
#       1 from openai import OpenAI
#       3 client = OpenAI(
#       4     api_key="sk-9de21cd0776947ec9ef2396f7110cb6d",  # Replace with your ModelScope SDK Token, see: https://modelscope.cn/my/myaccesstoken
#       5     base_url="https://api-inference.modelscope.cn/v1/"
#       6 )
# ----> 8 response = client.chat.completions.create(
#       9     model="Qwen/Qwen3-32B",    # ModelScope model_id
#      10     messages=[
#      11         {
#      12             'role': 'system',
#      13             'content': 'You are a helpful assistant.'
#      14         },
#      15         {
#      16             'role': 'user',
#      17             'content': 'Write a quicksort in Python.'
#      18         }
#      19     ],
#      20     stream=True
#      21 )
#      23 for chunk in response:
# ...

# %% [markdown]
# ### 性能测试
#     evalscope perf \
#         --model Qwen/Qwen3-32B \
#         --url "https://api-inference.modelscope.cn/v1/chat/completions" \
#         --api-key "YOUR_MODELSCOPE_SDK_TOKEN" \
#         --parallel 5 \
#         --number 20 \
#         --api openai \
#         --dataset openqa \
#         --stream \
#         --wandb-api-key "YOUR_WANDB_API_KEY"  # Optional
